# %%
import pandas as pd

# %%
df = pd.read_csv("../datasets/sentiment_reviews.csv")

# %%
df.tail()
# Out:
#                  sku                product_name  price product_category  \
# 31809  8906087770183  Stretch Marks Cream, 100ml    500       pregenancy
# 31810  8906087770183  Stretch Marks Cream, 100ml    500       pregenancy
# 31811  8906087770183  Stretch Marks Cream, 100ml    500       pregenancy
# 31812  8906087770183  Stretch Marks Cream, 100ml    500       pregenancy
# 31813  8906087770183  Stretch Marks Cream, 100ml    500       pregenancy
#
#       pack_size  review_count review_date review_time  price_rating  \
# 31809     100ml            54  2020-05-15    07:27:29             5
# 31810     100ml            54  2020-02-28    22:26:28             5
# 31811     100ml            54  2020-02-28    22:25:53             5
# 31812     100ml            54  2020-02-28    22:21:21             3
# 31813     100ml            54  2020-02-28    22:21:20             3
#
#        quality_rating  ...  month_of_creation day_of_creation  \
# 31809               0  ...                  3              25
# 31810               0  ...                  3              25
# 31811               0  ...                  3              25
# 31812               0  ...                  3              25
# 31813               0  ...                  3              25
#
#       last_updated_year last_updated_month last_updated_day  \
# 31809              2021                  9               13
# 31810              2021                  9               13
# 31811              2021                  9               13
# 31812              2021                  9               13
# 31813              2021                  9               13
#
#                                   cleaned_review_content  sentiment_score  \
# 31809                                       nice product           0.4215
# 31810                      mama earth product nice super           0.7717
# 31811  mamaearth stretch mark cream effective using s...           0.4767
# 31812  gifted friend product made skin soft lighten s...           0.7845
# 31813  gifted friend product made skin soft lighten s...           0.4939
#
#        positive_count  negative_count  sentiment
# 31809               1               0          1
# 31810               2               0          1
# 31811               1               0          1
# 31812               2               0          1
# 31813               1               0          1
#
# [5 rows x 27 columns]

# %%
g = df[['sku','positive_count', 'negative_count']]

# %%
g['total'] = g['positive_count'] - g['negative_count']
# Out:
# /tmp/ipykernel_240811/1144841252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   g['total'] = g['positive_count'] - g['negative_count']

# %%
g
# Out:
#                  sku  positive_count  negative_count  total
# 0      8904417301922               0               0      0
# 1      8904417301915               0               0      0
# 2      8904417301908               0               0      0
# 3      8904417301892               0               0      0
# 4      8904417303377               1               0      1
# ...              ...             ...             ...    ...
# 31809  8906087770183               1               0      1
# 31810  8906087770183               2               0      2
# 31811  8906087770183               1               0      1
# 31812  8906087770183               2               0      2
# 31813  8906087770183               1               0      1
#
# [31814 rows x 4 columns]

# %%
df
# Out:
#                  sku                                       product_name  \
# 0      8904417301922  Moisture Matte Longstay Lipstick - 2g | Citrus...
# 1      8904417301915  Moisture Matte Longstay Lipstick - 2g | Berryl...
# 2      8904417301908  Moisture Matte Longstay Lipstick -2g  | Cherry...
# 3      8904417301892  Moisture Matte Long Stay Lipstick - 2g | Pink ...
# 4      8904417303377  Vitamin C Daily Glow Face Cream - 80 g - Pack ...
# ...              ...                                                ...
# 31809  8906087770183                         Stretch Marks Cream, 100ml
# 31810  8906087770183                         Stretch Marks Cream, 100ml
# 31811  8906087770183                         Stretch Marks Cream, 100ml
# 31812  8906087770183                         Stretch Marks Cream, 100ml
# 31813  8906087770183                         Stretch Marks Cream, 100ml
#
#        price product_category pack_size  review_count review_date review_time  \
# 0        499             face        2g             0           0           0
# 1        499            other        2g             0           0           0
# 2        499             face        2g             0           0           0
# 3        499             face        2g             0           0           0
# 4        498             skin       80g             2  2022-09-13    18:33:56
# ...      ...              ...       ...           ...         ...         ...
# 31809    500       pregenancy     100ml            54  2020-05-15    07:27:29
# 31810    500       pregenancy     100ml            54  2020-02-28    22:26:28
# 31811    500       pregenancy     100ml            54  2020-02-28    22:25:53
# 31812    500       pregenancy     100ml            54  2020-02-28    22:21:21
# 31813    500       pregenancy     100ml            54  2020-02-28    22:21:20
#
#        price_rating  quality_rating  ...  month_of_creation day_of_creation  \
# 0                 0               0  ...                  9              13
# 1                 0               0  ...                  9              13
# 2                 0               0  ...                  9              13
# 3                 0               0  ...                  9              13
# 4                 5               0  ...                  9               1
# ...             ...             ...  ...                ...             ...
# 31809             5               0  ...                  3              25
# 31810             5               0  ...                  3              25
# 31811             5               0  ...                  3              25
# 31812             3               0  ...                  3              25
# 31813             3               0  ...                  3              25
#
#       last_updated_year last_updated_month last_updated_day  \
# 0                  2022                  9               19
# 1                  2022                  9               19
# 2                  2022                  9               19
# 3                  2022                  9               19
# 4                  2022                  9               12
# ...                 ...                ...              ...
# 31809              2021                  9               13
# 31810              2021                  9               13
# 31811              2021                  9               13
# 31812              2021                  9               13
# 31813              2021                  9               13
#
#                                   cleaned_review_content  sentiment_score  \
# 0                                                    NaN           0.0000
# 1                                                    NaN           0.0000
# 2                                                    NaN           0.0000
# 3                                                    NaN           0.0000
# 4                                                   like           0.3612
# ...                                                  ...              ...
# 31809                                       nice product           0.4215
# 31810                      mama earth product nice super           0.7717
# 31811  mamaearth stretch mark cream effective using s...           0.4767
# 31812  gifted friend product made skin soft lighten s...           0.7845
# 31813  gifted friend product made skin soft lighten s...           0.4939
#
#        positive_count  negative_count  sentiment
# 0                   0               0          0
# 1                   0               0          0
# 2                   0               0          0
# 3                   0               0          0
# 4                   1               0          1
# ...               ...             ...        ...
# 31809               1               0          1
# 31810               2               0          1
# 31811               1               0          1
# 31812               2               0          1
# 31813               1               0          1
#
# [31814 rows x 27 columns]

# %%
df['sentiment'] = g['total'].apply(lambda x : x > 0).replace({False : 0, True : 1})

# %%
df.to_csv("sentiment_reviews.csv", index=False)

# %%
bad = g[g['total'] == 0]

# %%
good = g[g['total'] == 1]

# %%
bad
# Out:
#                  sku  positive_count  negative_count  total
# 0      8904417301922               0               0      0
# 1      8904417301915               0               0      0
# 2      8904417301908               0               0      0
# 3      8904417301892               0               0      0
# 6      8904417300048               0               0      0
# ...              ...             ...             ...    ...
# 31784  8906087770183               0               0      0
# 31788  8906087770183               0               0      0
# 31790  8906087770183               0               0      0
# 31799  8906087770183               0               0      0
# 31800  8906087770183               0               0      0
#
# [2619 rows x 4 columns]

# %%
good
# Out:
#                  sku  positive_count  negative_count  total
# 4      8904417303377               1               0      1
# 5      8904417303377               1               0      1
# 11     8904417302318               1               0      1
# 12     8904417302318               1               0      1
# 13     8904417302318               1               0      1
# ...              ...             ...             ...    ...
# 31807  8906087770183               1               0      1
# 31808  8906087770183               1               0      1
# 31809  8906087770183               1               0      1
# 31811  8906087770183               1               0      1
# 31813  8906087770183               1               0      1
#
# [16957 rows x 4 columns]

# %%
# Out:
#                  sku  positive_count  negative_count  total
# 40     8904417300338               0               3     -3
# 113    8904417301106               0               1     -1
# 136    8904417301106               0               1     -1
# 202    8904417301090               0               1     -1
# 573    8904417301069               0               1     -1
# ...              ...             ...             ...    ...
# 30114  8906087770664               0               1     -1
# 31263  8906087770152               0               2     -2
# 31285  8906087770152               0               1     -1
# 31356  8906087770534               0               1     -1
# 31357  8906087770534               0               1     -1
#
# [166 rows x 4 columns]

# %%
g[g['sku'] == "8906087770183"]['total'].sum()
# Out:
# 84

# %%
p = pd.read_csv("sentiment_reviews.csv")

# %%
p[p['sentiment'] == 0]['review_content']
# Out:
# 0                                                        0
# 1                                                        0
# 2                                                        0
# 3                                                        0
# 6                                                        0
#                                ...
# 31784    i had deep stretch marks on my tummy for fat i...
# 31788                                                  gud
# 31790           i am using this product it's really gud ..
# 31799    this pregnancy stretch mark cream intensly hyd...
# 31800    this pregnancy stretch mark cream intensly hyd...
# Name: review_content, Length: 2881, dtype: object

# %%
from collections import Counter

# %%
c = Counter(p[p['sentiment'] == 1]['review_content'])

# %%
c.most_common(100)
# Out:
# [('good', 570),
#  ('good product', 361),
#  ('nice', 361),
#  ('nice product', 354),
#  ('like', 288),
#  ('good product ', 263),
#  ('nice product ', 237),
#  ('good ', 226),
#  ('very good product', 153),
#  ('nice ', 143),
#  ('very good product ', 141),
#  ('i like this product', 137),
#  ('very good', 137),
#  ('i like it', 124),
#  ('very nice', 124),
#  ('very nice product ', 117),
#  ('very nice product', 116),
#  ('super', 107),
#  ('i like this product ', 95),
#  ('awesome', 93),
#  ('awesome ', 90),
#  ('amazing product', 87),
#  ('very nice ', 83),
#  ('very good ', 78),
#  ('awesome product', 76),
#  ('excellent ', 74),
#  ('best product ', 74),
#  ('amazing', 73),
#  ('amazing product ', 69),
#  ('i love this product ', 69),
#  ('best product', 68),
#  ('loved it', 64),
#  ('nice products', 62),
#  ('awesome product ', 62),
#  ('super ', 57),
#  ('amazing ', 57),
#  ('love it', 54),
#  ('i love it', 53),
#  ('excellent product', 52),
#  ('like ', 51),
#  ('i like it ', 51),
#  ('like it', 50),
#  ('i love this product', 50),
#  ('best', 49),
#  ('excellent', 48),
#  ('great product', 45),
#  ('excellent product ', 40),
#  ("it's amazing ", 40),
#  ('best products', 36),
#  ('super product', 33),
#  ('best ', 32),
#  ('like this product', 31),
#  ('very good products', 31),
#  ('i love it ', 30),
#  ('superb ', 29),
#  ('nice products ', 28),
#  ("it's good", 27),
#  ('good products', 27),
#  ('superb', 26),
#  ('love this product', 24),
#  ('very nice products', 21),
#  ('love it ', 21),
#  ('good one', 21),
#  ('amazing products', 21),
#  ('really good ', 19),
#  ('good products ', 19),
#  ('great', 19),
#  ("it's amazing", 19),
#  ('these body lotion are very good and  the fragrance of both the body lotions is also  very nice ☺️',
#   18),
#  ('superb product', 18),
#  ('really good', 17),
#  ('wow', 17),
#  ('i like the product', 17),
#  ('this product is good for acne prone skin it also reduces the acne or pimple spots ❤❤, i used this face gel cream only in night❤',
#   17),
#  ('super product ', 16),
#  ('i like ', 16),
#  ('great product ', 16),
#  ("it's awesome", 16),
#  ('very wonderful product ', 16),
#  ('i loved it', 15),
#  ('just wow', 15),
#  ('i love your products ', 15),
#  ('good face wash ', 14),
#  ("it's really good ", 14),
#  ('very effective ', 14),
#  ('good result', 14),
#  ('i like all products in mamaaearth i like all all shopping apps', 14),
#  ('just awesome', 13),
#  ('loved it ', 13),
#  ('best products ', 13),
#  ('i loved it ', 13),
#  ('awesome products', 13),
#  ('its good', 13),
#  ('m in love with this product !it is very light weighted and  smells very good n feel relaxing after using this !!! value for money product m totally in love this this!!',
#   13),
#  ('good quality ', 12),
#  ('awesome products ', 12),
#  ('great ', 12),
#  ('very effective', 12),
#  ('liked it', 12),
#  ('i like this', 12)]

# %%
q = p['price'].value_counts().reset_index()

# %%
d = {
    "price" : list(q['price']),
    "order_count" : list(q['count'])
}

# %%
d
# Out:
# {'price': [399,
#   349,
#   599,
#   499,
#   249,
#   299,
#   259,
#   319,
#   699,
#   1097,
#   449,
#   471,
#   375,
#   199,
#   149,
#   698,
#   498,
#   1297,
#   999,
#   1177,
#   1696,
#   798,
#   748,
#   1396,
#   598,
#   948,
#   419,
#   1346,
#   508,
#   799,
#   720,
#   1197,
#   500,
#   1247,
#   150,
#   608,
#   398,
#   750,
#   648,
#   908,
#   559,
#   1198,
#   1746,
#   1497,
#   518,
#   448,
#   1098,
#   1243,
#   1193,
#   447],
#  'order_count': [6439,
#   4146,
#   4023,
#   2809,
#   2750,
#   2030,
#   1208,
#   1139,
#   914,
#   696,
#   626,
#   615,
#   606,
#   556,
#   392,
#   341,
#   310,
#   175,
#   172,
#   171,
#   165,
#   142,
#   135,
#   117,
#   115,
#   111,
#   104,
#   85,
#   70,
#   65,
#   59,
#   54,
#   54,
#   53,
#   44,
#   40,
#   35,
#   32,
#   31,
#   28,
#   28,
#   26,
#   25,
#   23,
#   20,
#   18,
#   13,
#   2,
#   1,
#   1]}
